# %% [markdown]
# <a href="https://colab.research.google.com/github/CharleneLimKH/python-mini-projects/blob/main/Class_exercise_drug_pulse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
  
  
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a862e906-0dc2-456b-a2b8-819304e9973c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a862e906-0dc2-456b-a2b8-819304e9973c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
  
df = pd.read_csv(io.BytesIO(uploaded['drug_pulse_2.csv']))
# write a code that gives a summary of the statistics of the data
df.describe()
# Out:
#                 age           sex  pulse change
# count  10100.000000  10100.000000  10100.000000
# mean       0.952376      0.008119      0.350000
# std       58.490737      0.707095     17.756117
# min     -100.000000     -1.000000    -30.000000
# 25%      -50.000000      0.000000    -15.000000
# 50%        3.000000      0.000000      1.000000
# 75%       52.000000      1.000000     16.000000
# max      101.000000      1.000000     30.000000

# %%
# Separate the data into two data frames of different genders 
df1=df[df.sex == 1]
df0=df[df.sex == 0]
df0
# Out:
#        age  sex  pulse change
# 50      31    0            -5
# 51      45    0            17
# 52      89    0             2
# 53      95    0            21
# 54      57    0            25
# ...    ...  ...           ...
# 10095  -84    0            30
# 10096  -76    0            27
# 10097  -99    0            23
# 10098   27    0            -1
# 10099   48    0            -2
#
# [5050 rows x 3 columns]

# %%
# Here, we concat both 
df3=pd.concat([df0,df1],axis=1)
#Make a boxplot
boxplot = df.boxplot(figsize = (10,10))

# %%
#Compute the correlation on the original data frame
df.corr()
# Out:
#                    age       sex  pulse change
# age           1.000000  0.000706      0.014838
# sex           0.000706  1.000000      0.003701
# pulse change  0.014838  0.003701      1.000000

# %%
#Let us plot the pulse change against the age
df.plot.scatter(x='age',y='pulse change',c='DarkBlue')

# %%
# Now let us separate the data into two data frames according to the age 
df2=df[df.age <= 42 ]
df3=df[df.age > 42 ]
#df1

# %%
#concat data again and use box plot, what do you observe?
df4=pd.concat([df2,df3],axis=1)
#Make a boxplot
boxplot = df4.boxplot(figsize = (10,10))
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
